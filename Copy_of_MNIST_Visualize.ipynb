# %% [markdown]
# <a href="https://colab.research.google.com/github/majid1363/majid1363/blob/main/Copy_of_MNIST_Visualize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
import numpy as np
from matplotlib import pyplot as plt

# %%
# load dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
print('x_train is {}'.format(x_train.shape))
print('y_train is {}'.format(y_train.shape))
print('x_test  is {}'.format(x_test.shape))
print('y_test  is {}'.format(y_test.shape))
# Out:
# x_train is (60000, 28, 28)
# y_train is (60000,)
# x_test  is (10000, 28, 28)
# y_test  is (10000,)

# %%
# show some samples of the dataset
plt.figure(figsize=(25,4))
for i in range(8):
  plt.subplot(1,8,i+1)
  plt.imshow(x_train[i], cmap='gray')
  plt.xticks([])
  plt.yticks([])
  plt.title(y_train[i])

# %%
h = np.zeros(10)
for n in range(y_train.shape[0]):
  h[y_train[n]] += 1

print(h)
plt.stem(h)
# Out:
# [5923. 6742. 5958. 6131. 5842. 5421. 5918. 6265. 5851. 5949.]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
rows = 10
cols = 20
h = np.zeros(rows)
image = np.ones((30*rows, 30*cols))*255
for n in range(y_train.shape[0]):
  if h[y_train[n]] < cols:
    r = int(y_train[n])
    c = int(h[y_train[n]])
    image[r*30+1:(r+1)*30-1, c*30+1:(c+1)*30-1] = x_train[n]

  h[y_train[n]] += 1

plt.figure(figsize=(10, 10))
plt.imshow(image, 'gray')
plt.xticks([])
plt.yticks([])
plt.axis('off');

# %%
nums = 10
image = np.ones((30*1, 30*nums))*255
for n in range(nums):
  ind = np.where(y_train == n)
  image[1:29, n*30:(n+1)*30-2] = np.average(x_train[ind], axis=0)
    
plt.figure(figsize=(10, 10))
plt.imshow(image, 'gray')
plt.xticks([])
plt.yticks([])
plt.axis('off');
